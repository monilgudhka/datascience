# %% [markdown]
# Los Angeles Traffic Collision

# %%
# Importing libraries
import pandas as pd

# %% [markdown]
# Loading Data

# %%
traffic_collision_df = pd.read_csv('data/traffic-collision-data-from-2010-to-present.csv', index_col='DR Number')
traffic_collision_df.head()
# Out:
#                      Date Reported            Date Occurred  Time Occurred  \
# DR Number
# 190614534  2019-06-29T00:00:00.000  2019-06-29T00:00:00.000           1000
# 190411644  2019-06-29T00:00:00.000  2019-06-29T00:00:00.000            710
# 190913064  2019-06-29T00:00:00.000  2019-06-29T00:00:00.000            710
# 191217109  2019-06-29T00:00:00.000  2019-06-29T00:00:00.000            125
# 191011660  2019-06-29T00:00:00.000  2019-06-29T00:00:00.000             40
#
#            Area ID    Area Name  Reporting District  Crime Code  \
# DR Number
# 190614534        6    Hollywood                 626         997
# 190411644        4   Hollenbeck                 479         997
# 190913064        9     Van Nuys                 923         997
# 191217109       12  77th Street                1245         997
# 191011660       10  West Valley                1005         997
#
#           Crime Code Description                       MO Codes  Victim Age  \
# DR Number
# ...

# %% [markdown]
# Cleaning Data

# %%
traffic_collision_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478415 entries, 190614534 to 100104049
# Data columns (total 23 columns):
# Date Reported                        478415 non-null object
# Date Occurred                        478415 non-null object
# Time Occurred                        478415 non-null int64
# Area ID                              478415 non-null int64
# Area Name                            478415 non-null object
# Reporting District                   478415 non-null int64
# Crime Code                           478415 non-null int64
# Crime Code Description               478415 non-null object
# MO Codes                             393593 non-null object
# Victim Age                           400964 non-null float64
# Victim Sex                           471443 non-null object
# Victim Descent                       470724 non-null object
# Premise Code                         478390 non-null float64
# Premise Description                  478390 non-null object
# ...

# %% [markdown]
# Points to note
# 1. Date Reported is in string
# 2. Date Occurred is in string
# 3. Merge Date Occured and Time Occurred
# 4. MO Codes has NANs and list of Codes
# 5. Victim Sex, Descent has NANs and can be converted to category
# 6. Location is python's dictionary

# %%
traffic_collision_df.loc[:,['Victim Age','Victim Sex','Victim Descent','Premise Code']].head()
# Out:
#            Victim Age Victim Sex Victim Descent  Premise Code
# DR Number
# 190614534         NaN          M              W         101.0
# 190411644        25.0          M              H         101.0
# 190913064        35.0          M              H         101.0
# 191217109        34.0          M              B         101.0
# 191011660        50.0          F              H         101.0
